# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rasheed89034/ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
import os, sys, subprocess
import pandas as pd

# 1. Colab mein data download karne ka setup
IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)

# 2. Data load karna
path = "data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(path)

print(f"Loaded dataset with {df.shape[0]} pages.")
print("This is our playground to find pages that need a refresh.")
# Out:
# Loaded dataset with 30000 pages.
# This is our playground to find pages that need a refresh.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

down_count = df[df['trend_direction'] == 'down'].shape[0]
total = df.shape[0]

print(f"Cost Context: Out of {total} total pages, {down_count} ({down_count/total:.1%}) are actively trending 'down'.")
print("Our goal is to accurately rank these declining pages so writers don't waste time on the wrong ones.")
# Out:
# Cost Context: Out of 30000 total pages, 16262 (54.2%) are actively trending 'down'.
# Our goal is to accurately rank these declining pages so writers don't waste time on the wrong ones.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
corr = df["search_volume"].corr(df["impressions_90d"])
median_age_down = df[df['trend_direction'] == 'down']['content_age_days'].median()
median_age_stable = df[df['trend_direction'] == 'stable']['content_age_days'].median()

print(f"1. Volume vs Impressions Correlation: {corr:.3f} (Near zero)")
print(f"2. Median age of 'down' (declining) pages: {median_age_down} days")
print(f"3. Median age of 'stable' pages: {median_age_stable} days")
# Out:
# 1. Volume vs Impressions Correlation: 0.001 (Near zero)
# 2. Median age of 'down' (declining) pages: 216.0 days
# 3. Median age of 'stable' pages: 300.0 days

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Verifying we only use observable, pre-decision features
leaky_cols = ['trend_pct', 'trend_direction']
safe_cols = [c for c in df.columns if c not in leaky_cols]

print("To keep our claims honest, we will build our model strictly on safe, observable features like:")
print(safe_cols[:5])
# Out:
# To keep our claims honest, we will build our model strictly on safe, observable features like:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level']

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
