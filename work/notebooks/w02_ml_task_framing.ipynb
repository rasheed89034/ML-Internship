# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rasheed89034/ML-Internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
task_type = "Scoring/Ranking"
primary_entity = "Resume-to-Job Alignment"
print(f"ML Task: {task_type} for {primary_entity}")
# Out:
# ML Task: Scoring/Ranking for Resume-to-Job Alignment

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# Dummy calculation of Precision@10
ultimate_target = "interview_status_binary" # 1 or 0
proxy_target = "expert_alignment_score" # Continuous 0.0 to 1.0
print(f"Targeting: {ultimate_target}, falling back to proxy: {proxy_target}")
# Out:
# Targeting: interview_status_binary, falling back to proxy: expert_alignment_score

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

top_10_results = [1, 1, 0, 1, 1, 1, 1, 0, 1, 1] # 1 = qualified, 0 = unqualified
precision_at_10 = sum(top_10_results) / len(top_10_results)

print(f"Current Precision@10: {precision_at_10} (Target: >= 0.80)")
# Out:
# Current Precision@10: 0.8 (Target: >= 0.80)

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd

# Mocking the ATS slice dataframe
data = {
    "applicant_id": ["A101", "A102"],
    "job_id": ["J-ML50", "J-ML50"],
    "parsed_skills": [["Python", "FastAPI", "SQLite"], ["Java", "Spring", "MySQL"]],
    "job_reqs": [["Python", "Backend", "API"], ["Python", "Backend", "API"]],
    "alignment_score": [0.88, 0.15]
}
df = pd.DataFrame(data)

print("Unit of analysis: One row = one applicant-job pair")
display(df)
# Out:
# Unit of analysis: One row = one applicant-job pair
#   applicant_id  job_id              parsed_skills                job_reqs  \
# 0         A101  J-ML50  [Python, FastAPI, SQLite]  [Python, Backend, API]
# 1         A102  J-ML50      [Java, Spring, MySQL]  [Python, Backend, API]
#
#    alignment_score
# 0             0.88
# 1             0.15

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
job_requirement = "REST API"
resume_text = "Built web endpoints using FastAPI"

# A fixed rule fails on semantic variations
rule_passed = job_requirement.lower() in resume_text.lower()

print(f"Exact match rule passed: {rule_passed}")
print("Embeddings are needed to map 'web endpoints' to 'REST API'.")
# Out:
# Exact match rule passed: False
# Embeddings are needed to map 'web endpoints' to 'REST API'.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
